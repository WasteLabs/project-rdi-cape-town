# %% [markdown]
# # Resource planning --- full

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# | Document info | |
# | --- | --- |
# | Area of interest: | Cape Town |
# | Planning type: | All REL type producers |
# | Prepared by: | Waste Labs (wastelabs.co) |
# | Prepared for: | Johan W. Joubert |
# | Contact: | elias@wastelabs.co |

# %%
# %load_ext kedro.ipython
# %reload_kedro
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.use_jedi=False
# Show all code cells outputs
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

import logging

logging.basicConfig(level=logging.INFO)

import pickle

#import chart_studio.plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)

#import cufflinks as cf

# cf.go_offline(connected=True)
# cf.set_config_file(colorscale="plotly", world_readable=True)

import os
import sys

import geopandas as gpd
import ipywidgets as widgets
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from GPSOdyssey import Kepler
from IPython.display import clear_output
from ipywidgets import fixed, interact, interact_manual, interactive
from keplergl import KeplerGl
from shapely import wkt

# sys.path.insert(0, '../../../mcarptif/')
# sys.path.insert(0, os.path.abspath('../../collection_diagnostics/'))
# sys.path.insert(0, os.path.abspath('../../OSM_processing/'))
import utils.process_gdf as process_gdf

# Extra options
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

from mcarptif.osmnx_network_extract.extract_grptif import NetworkExtract
from mcarptif.osmnx_network_extract.network_code import create_gdf, required_arc_plot
from mcarptif.solver.solve import solve_store_instance
from mcarptif.visualise.route_tables import RouteSummary
from utils.gdf_helpers import create_gdf


def df_style(df):
    if df[0] == "Total":
        return ["font-weight: bold"] * len(df)
    else:
        return [""] * len(df)
# Out:
# [07/01/23 00:46:40] INFO     Resolved project path as:                                              ]8;id=246556;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=263799;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#136\136]8;;\
#                              /Users/ejwillemse/dev/projects/project-rdi-cape-town.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/01/23 00:46:40] WARNING  /Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/importlib/__in ]8;id=921318;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=476229;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              it__.py:126: DeprecationWarning: `kedro.extras.datasets` is deprecated
#                              and will be removed in Kedro 0.19, install `kedro-datasets` instead by
#                              running `pip install kedro-datasets`.
#                                return _bootstrap._gcd_import(name[level:], package, level)
# [07/01/23 00:46:41] INFO     NumExpr defaulting to 8 threads.                                          ]8;id=595871;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/numexpr/utils.py\utils.py]8;;\:]8;id=537572;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/numexpr/utils.py#160\160]8;;\
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=7594;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=548403;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely
#                              GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS
#                              version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions
#                              between both will be slow.
#                                warnings.warn(
# [07/01/23 00:46:43] INFO     Kedro project Project RDI Cape Town                                    ]8;id=547992;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=421758;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#105\105]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=552885;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=768573;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#106\106]8;;\
#                              'pipelines'
#                     INFO     Resolved project path as:                                              ]8;id=908262;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=468485;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#136\136]8;;\
#                              /Users/ejwillemse/dev/projects/project-rdi-cape-town.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/01/23 00:46:43] INFO     Kedro project Project RDI Cape Town                                    ]8;id=286448;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=766421;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#105\105]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=714295;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=617016;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#106\106]8;;\
#                              'pipelines'
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [07/01/23 00:46:44] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=460001;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=955832;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning:
#
#                              Using slow pure-python SequenceMatcher. Install python-Levenshtein to
#                              remove this warning
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=259816;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=187073;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/pyximport/pyximport.py:51: DeprecationWarning:
#
#                              the imp module is deprecated in favour of importlib and slated for
#                              removal in Python 3.12; see the module's documentation for alternative
#                              uses

# %% [markdown]
# ## Load network data

# %%
networkh5_file = "../data/05_model_input/sp_files/road_network_simplified_24645.h"
test_network = catalog.load("road_network_simplified_24645_edges")
test_network = test_network.drop(columns=["Unnamed: 0"], errors="ignore")
test_network_directed = catalog.load("road_network_simplified_24645_edges_directed")
nodes = catalog.load("road_network_simplified_24645_nodes")
# Out:
# [07/01/23 00:46:45] INFO     Loading data from 'road_network_simplified_24645_edges'            ]8;id=125590;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=245762;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (GeoJSONDataSet)...
# [07/01/23 00:46:53] INFO     Loading data from 'road_network_simplified_24645_edges_directed'   ]8;id=679982;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=529829;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (GeoJSONDataSet)...
# [07/01/23 00:46:57] INFO     Loading data from 'road_network_simplified_24645_nodes'            ]8;id=385851;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=505732;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (GeoJSONDataSet)...

# %%
test_network.shape
# Out:
# (22189, 19)

# %%
# %%time
test_network = process_gdf.process_edges(test_network)
test_network.drop_duplicates(["geom_id"], inplace=True)
nodes.sp_index = nodes.index
test_network["arc_index"] = test_network.index
nodes["sp_index"] = nodes.index
# Out:
# [07/01/23 00:47:02] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=425299;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=256054;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/geopandas/geodataframe.py:205: UserWarning:
#
#                              Pandas doesn't allow columns to be created via a new attribute name -
#                              see
#                              https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-a
#                              ccess
# CPU times: user 2.71 s, sys: 69.8 ms, total: 2.78 s
# Wall time: 3.08 s

# %% [markdown]
# ## Run scenarios

# %%
# %%time
df_lat_lon_match = catalog.load("lat_lon_key_network_match_20220601_residential_streets_only")
df_producer_geo_all = catalog.load("syn_pop_scenarios_local_20220601")
infrastructure = catalog.load("infrastructure_sample_network_match")
solved = list(catalog.load("resource_summary_table_arcs_only_fixed_speed_20220601"))
# Out:
#                     INFO     Loading data from                                                  ]8;id=609951;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=783655;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              'lat_lon_key_network_match_20220601_residential_streets_only'
#                              (CSVDataSet)...
#                     INFO     Loading data from 'syn_pop_scenarios_local_20220601'               ]8;id=173707;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=398221;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Loading data from 'infrastructure_sample_network_match'            ]8;id=331456;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=462776;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (CSVDataSet)...
#                     INFO     Loading data from                                                  ]8;id=766731;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=391200;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              'resource_summary_table_arcs_only_fixed_speed_20220601'
#                              (PartitionedDataSet)...
# CPU times: user 55.7 ms, sys: 11.2 ms, total: 66.9 ms
# Wall time: 68.8 ms

# %%
# keys_all = list(df_producer_geo_all)
# key = keys_all[0]

# routing_parameters = catalog.load(
#     "routing_parameters"
# )
# df_producer_geo = df_producer_geo_all[key]()
# df_producer_geo_waste = catalog.load("waste_gen_scenarios_local_20220601")[key]()

def assign_demand(df_producer_geo, df_lat_lon_match, df_producer_geo_waste, routing_parameters):
    df_producer_geo["lat_lon_id"] = (
        df_producer_geo[["parcelLat", "parcelLon"]]
        .round(8)
        .astype(str)
        .agg("-".join, axis=1)
    )
    df_producer_geo = df_producer_geo.merge(df_lat_lon_match, left_on="lat_lon_id", right_on="lat_lon_id").drop_duplicates(["arc_id"])

    df_producer_geo = df_producer_geo.merge(
        test_network[["arc_id", "geom_id", "geom_id_inv", "geom_id_order", "arc_index"]],
        validate="m:1",
    )
    df_producer_geo["land_use"] = df_producer_geo["mainDwellingType"].fillna("nan")


    total_waste = df_producer_geo_waste["waste"].sum()
    n_bins = len(df_producer_geo_waste)
    df_producer_geo_waste = df_producer_geo_waste.loc[df_producer_geo_waste["id"] != 0.01]
    df_producer_geo_waste = df_producer_geo_waste.loc[df_producer_geo_waste["id"].isin(df_producer_geo["id"])]
    routing_parameters.fillna(0, inplace=True)

    calculate = ["bin_service_cost"]
    df_producer_geo.drop(columns=calculate, inplace=True, errors="ignore")
    df_producer_geo["Domestic"] = np.ceil( n_bins * ( df_producer_geo["dist_collect"] / df_producer_geo["dist_collect"].sum()) ).astype(int)
    df_producer_geo["Non Domestic"] = 0
    df_producer_geo["H/M"] = 0
    df_producer_geo["category"] = "Landed"
    df_producer_geo["land_use"] = "Landed"
    df_producer_geo["total units"] =  np.ceil( n_bins * ( df_producer_geo["dist_collect"] / df_producer_geo["dist_collect"].sum()) ).astype(int)
    df_producer_geo["total_people"] =  np.ceil( n_bins * ( df_producer_geo["dist_collect"] / df_producer_geo["dist_collect"].sum()) ).astype(int)
    df_producer_geo["Postal Code"] = df_producer_geo["id"]

    df_producer_geo = df_producer_geo.merge(routing_parameters)
    df_producer_geo = df_producer_geo.merge(
        df_producer_geo_waste, how="left", validate="1:1"
    )
    df_producer_geo["demand"] = total_waste * ( df_producer_geo["dist_collect"] / df_producer_geo["dist_collect"].sum())
    df_producer_geo["bin_service_cost"] = 0 #df_producer_geo["bin_service_cost"] * df_producer_geo["total units"]
    return df_producer_geo

# %%
# %reload_kedro
keys_all = list(df_producer_geo_all)
routing_parameters = catalog.load(
    "routing_parameters"
)
for keys in keys_all:
    if keys[0] == ".": continue
    if keys in solved: continue
    print(f"\n\n RUNNING SCENARIO {keys}")

    df_producer_geo = df_producer_geo_all[keys]()
    df_producer_geo_waste = catalog.load("waste_gen_scenarios_local_20220601")[keys]()
    df_producer_geo = assign_demand(df_producer_geo, df_lat_lon_match, df_producer_geo_waste, routing_parameters)
 
    # print("\n# offloads (12t)")
    # df_producer_geo.groupby("land_use")["demand"].sum() / 12000  # number of offloads
    # print("\n# units")
    # df_producer_geo.groupby("land_use")["total units"].sum()
    # print("\n# shifts (bin service cost)")
    # df_producer_geo.groupby("land_use")["bin_service_cost"].sum() / (
    #     3600 * 8
    # )  # number of shifts

    key_pois = infrastructure
    key_pois["Postal Code"] = key_pois["id"]

    key_pois["u"] = key_pois["arc_u"]
    key_pois["v"] = key_pois["arc_v"]
    key_pois["key"] = 0
    key_pois["geometry_point"] = key_pois["geometry"]
    key_pois["geometry"] = key_pois["geometry_arc"]
    key_pois = process_gdf.process_edges(key_pois)
    key_pois["geometry"] = key_pois["geometry_point"]
    key_pois = key_pois.merge(test_network[["arc_id", "arc_index"]], validate="1:1")

    offload = key_pois.loc[(key_pois["type"] != "depot")]

    key_depos = key_pois.loc[key_pois["type"] == "depot"]
    key_pois_list = list(key_depos["description"].unique())

    description = "Depot 2"

    key_depot_select = key_depos.copy()
    key_depot_select = key_depot_select.loc[key_depot_select["description"] == description]
    depot_arc_index = key_depot_select.iloc[0]["arc_index"]
    offload = key_pois.loc[key_pois["type"] != "depot"]

    descriptions = ["Offload 2", "Offload 3"]

    key_if_select = offload.copy()
    key_if_select = key_if_select.loc[key_if_select["description"].isin(descriptions)]
    if_arc_index = key_if_select["arc_index"].values

    key_list = list(df_producer_geo["category"].unique())

    descriptions = ["Landed"]

    bad_arcs = [
        "[(18.4571747, -33.9584372), (18.457166, -33.9585368), (18.457156, -33.9585885), (18.4571405, -33.9586324), (18.4571204, -33.9586875), (18.4570842, -33.9587648), (18.4568647, -33.9591331), (18.4568633, -33.9591415), (18.4568634, -33.9591465), (18.4568651, -33.9591518), (18.4568693, -33.9591571), (18.4568826, -33.9591636), (18.4570165, -33.9592207), (18.4570237, -33.9592212), (18.4570302, -33.9592194), (18.4570376, -33.9592149), (18.4570447, -33.9592066), (18.4570542, -33.9591921), (18.457325, -33.958752), (18.4573407, -33.9587173), (18.4573555, -33.9586744), (18.4573665, -33.9586219), (18.4573672, -33.9585957), (18.4573652, -33.958564), (18.4573568, -33.9585404), (18.4573451, -33.9585162), (18.457334, -33.9585017), (18.4573196, -33.9584906), (18.4573008, -33.9584812), (18.457278, -33.9584717), (18.4571747, -33.9584372)]"
    ]

    prod_select = df_producer_geo.copy()
    prod_select = prod_select.loc[~prod_select["geom_id_order"].isin(bad_arcs)]
    prod_select = prod_select.loc[prod_select["category"].isin(descriptions)]

    logging.info("Preparing road network.......\n")
    nodes["u"] = nodes["osmid"]
    network_info = NetworkExtract(
        test_network,
        test_network_directed,
        nodes,
        networkh5_file,
        round_cost=True,
        key_pois=key_pois,
    )
    
    depot = depot_arc_index
    ifs = if_arc_index
    req_arcs = network_info.arc_consolidation_standard(prod_select)
    network_info.load_required_arcs(req_arcs, merge_network=True)
    network_info.set_depot_arc(depot)
    network_info.set_if_arcs(ifs)
    network_info.loc_in_required_arcs()

    network_info.extend_required_inverse_arcs()

    network_info.check_main_list()
    network_info.load_distance_matrix()
    network_info.offload_calculations3D()

    network_info.network_gdf(prod_select)

    logging.info("Done!")

    cut_off = 100000
    bad_arcs = []
    for i in range(len(network_info.d)):
        if network_info.d[i, 0] > cut_off:
            bad_arc = network_info.reqArcList[i]
            bad_links = test_network.loc[test_network["arc_index"] == bad_arc]
            bad_arcs += bad_links["geom_id_order"].tolist()
    assert len(bad_arcs) == 0
    

    cut_off = 100000
    bad_arcs = []
    for i in range(len(network_info.d)):
        if network_info.d[0, i] > cut_off:
            bad_arc = network_info.reqArcList[i]
            bad_links = test_network.loc[test_network["arc_index"] == bad_arc]
            bad_arcs += bad_links["geom_id_order"].tolist()
    assert len(bad_arcs) == 0
    

    d_max = network_info.d.max()
    if d_max == np.inf:
        d_i = network_info.d.argmax(axis=0)[0]
        bad_arc = network_info.reqArcList[d_i]
        print(network_info.d[d_i, :])
        print(network_info.d[:, d_i])
        d_i2 = network_info.d[d_i, :].argmax()
        bad_arc2 = network_info.reqArcList[d_i2]
        print(network_info.d[d_i2, :])
        print(network_info.d[:, d_i2])
        test_network.loc[test_network["arc_index"] == bad_arc]
        test_network.loc[test_network["arc_index"] == bad_arc2]

    scenario_name = "Landed refuse"
    schedule_select = "weekly"
    offload_time = 15 * 60
    max_duration = 10.5 * 3600
    capacity = 10.5 * 1000
    travel_speed = 45 / 3.6
    service_speed = 5 / 3.6 #35 / 3.6

    demand_increase_factor = {"daily": 1, "weekly": 1, "two_one": 1}
    increase_factor = demand_increase_factor[schedule_select]

    logging.info("Uploading scenario inputs...")
    prod_select_update = prod_select.copy()
    prod_arc_update = prod_select_update.copy()

    network_info.producer_demand = prod_arc_update
    prod_arc_update = network_info.add_demand_service_cost_to_ars(
        prod_select_update, service_speed
    )
    _ = pd.DataFrame(
        prod_arc_update.drop(columns=["arc_index"]).sum(numeric_only=True)
    ).astype(int)

    network_info.set_travel_speed(travel_speed)
    network_info.set_service_cost_and_demand(prod_arc_update)
    network_info.set_offload_time(offload_time)
    network_info.check_shapes()

    network_info.update_cost_matrix()
    network_info.update_offload_cost()

    network_info.set_vechile_capacity_constraint(capacity)
    network_info.set_vehicle_duration_constraint(max_duration)
    logging.info("Done")

    solution_df = solve_store_instance(
        "",
        improve=None,
        write_results=False,
        info=network_info,
        overwrite=True,
        test_solution=False,
        full_output=False,
        tollerance=60,
        nnFracLS=1,
        nnFracTS=0.25,
    )
    logging.info("Done generating routes")
    n_route = solution_df["route"].max() + 1
    print(f"Number of routes: {n_route}")

    logging.info("Preparing scenario outputs...")

    network_info.extend_prop_info()
    network_info.add_solution(solution_df, order=False)
    network_info.deconstruct_solution()

    network_info.vehicle_collection_schedule(schedule=schedule_select)
    network_info.extract_wide_offload_totals()

    network_info.add_traversal_time()
    network_info.add_time_formatted()
    network_info.add_constant_duration_time()

    _ = network_info.full_producer_report()

    route_summary = RouteSummary(network_info)
    route_sum_table = route_summary.route_summary()
    logging.info("Done preparing output")
    catalog.save("resource_summary_table_arcs_only_fixed_speed_20220601", {keys: route_sum_table})
# Out:
#                     INFO     Resolved project path as:                                              ]8;id=707411;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=756800;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#136\136]8;;\
#                              /Users/ejwillemse/dev/projects/project-rdi-cape-town.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/01/23 00:47:03] INFO     Kedro project Project RDI Cape Town                                    ]8;id=706266;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=879428;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#105\105]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=716163;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=59584;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#106\106]8;;\
#                              'pipelines'
#                     INFO     Loading data from 'routing_parameters' (ExcelDataSet)...           ]8;id=903140;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=22427;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#  RUNNING SCENARIO households_062
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=579869;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=260016;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
# [07/01/23 00:47:04] INFO     Preparing road network.......                                         ]8;id=781963;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=794297;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=139966;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=313440;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=53671;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=288412;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=257456;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=204805;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=873425;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=837567;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=646725;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=959176;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=484377;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=765280;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     ERROR    Depot cannot have inverse arc.                                   ]8;id=28163;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=204672;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#402\402]8;;\
#                     INFO     Load distance matrix: 7600 x 7600                                ]8;id=589194;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=567265;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:47:11] INFO     Creating nearest neighbour lists                                 ]8;id=937715;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=717679;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:47:14] INFO     Calculate offloads: 7600 x 7600 x 2                              ]8;id=888097;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=563208;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:47:25] INFO     Done!                                                                 ]8;id=546817;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=197401;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=953713;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=374251;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=735102;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=938897;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=955725;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=261497;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=672375;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=189723;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
# [07/01/23 00:47:26] INFO     Update offload durations.                                        ]8;id=10348;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=70591;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
#                     INFO     Done                                                                 ]8;id=468632;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=987563;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=554548;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=373269;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:47:55] INFO     Done generating routes                                               ]8;id=216753;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=689566;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#175\175]8;;\
# Number of routes: 8
#                     INFO     Preparing scenario outputs...                                        ]8;id=505775;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=483310;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#179\179]8;;\
# [07/01/23 00:48:08] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=506683;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=241557;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=492614;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=174767;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=782145;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=692464;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#196\196]8;;\
#                     INFO     Saving data to                                                     ]8;id=596492;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=329305;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              'resource_summary_table_arcs_only_fixed_speed_20220601'
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_063
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=958;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=179452;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Preparing road network.......                                         ]8;id=19134;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=379590;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=175024;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=259482;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=686881;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=801539;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=528572;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=866853;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=261365;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=905102;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=687928;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=571146;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
# [07/01/23 00:48:09] INFO     Checking master list                                             ]8;id=673642;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=813995;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     ERROR    Depot cannot have inverse arc.                                   ]8;id=235587;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=223153;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#402\402]8;;\
#                     INFO     Load distance matrix: 7532 x 7532                                ]8;id=339671;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=118234;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:48:15] INFO     Creating nearest neighbour lists                                 ]8;id=586590;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=867663;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:48:18] INFO     Calculate offloads: 7532 x 7532 x 2                              ]8;id=120898;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=443656;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:48:29] INFO     Done!                                                                 ]8;id=173234;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=710051;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=536584;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=109493;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=975795;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=471337;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=467595;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=759349;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=160637;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=487217;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
#                     INFO     Update offload durations.                                        ]8;id=750159;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=822978;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
# [07/01/23 00:48:30] INFO     Done                                                                 ]8;id=435049;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=390630;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=355808;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=674639;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:48:57] INFO     Done generating routes                                               ]8;id=170531;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=376790;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#175\175]8;;\
# Number of routes: 8
#                     INFO     Preparing scenario outputs...                                        ]8;id=698481;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=986713;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#179\179]8;;\
# [07/01/23 00:49:11] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=855629;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=318467;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=184705;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=769958;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=188504;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=503882;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#196\196]8;;\
#                     INFO     Saving data to                                                     ]8;id=156570;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=862753;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              'resource_summary_table_arcs_only_fixed_speed_20220601'
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_064
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=512517;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=631579;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
# [07/01/23 00:49:12] INFO     Preparing road network.......                                         ]8;id=997835;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=864597;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=970737;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=623770;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=221796;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=336926;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=66570;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=533938;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=800918;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=229985;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=634969;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=127661;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=834396;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=884782;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     ERROR    Depot cannot have inverse arc.                                   ]8;id=486538;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=466889;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#402\402]8;;\
#                     INFO     Load distance matrix: 7552 x 7552                                ]8;id=405041;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=9863;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:49:19] INFO     Creating nearest neighbour lists                                 ]8;id=99652;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=393669;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:49:22] INFO     Calculate offloads: 7552 x 7552 x 2                              ]8;id=27832;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=612938;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:49:32] INFO     Done!                                                                 ]8;id=339296;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=25176;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=867749;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=646316;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=591390;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=533055;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=409312;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=427378;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=115335;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=568540;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
#                     INFO     Update offload durations.                                        ]8;id=148903;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=569211;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
#                     INFO     Done                                                                 ]8;id=799653;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=364731;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=799895;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=810451;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:49:57] INFO     Done generating routes                                               ]8;id=695967;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=894610;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#175\175]8;;\
# Number of routes: 8
#                     INFO     Preparing scenario outputs...                                        ]8;id=388789;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=801182;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#179\179]8;;\
# [07/01/23 00:50:08] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=954366;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=586273;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=376032;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=706497;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=232846;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=730561;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#196\196]8;;\
#                     INFO     Saving data to                                                     ]8;id=7788;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=607251;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              'resource_summary_table_arcs_only_fixed_speed_20220601'
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_065
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=335408;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=520108;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
# [07/01/23 00:50:09] INFO     Preparing road network.......                                         ]8;id=840164;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=592530;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=492318;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=114714;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=959690;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=300823;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=394398;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=276185;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=244861;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=495234;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=845346;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=604435;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=541332;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=643018;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     ERROR    Depot cannot have inverse arc.                                   ]8;id=606909;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=746341;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#402\402]8;;\
#                     INFO     Load distance matrix: 7615 x 7615                                ]8;id=389845;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=216103;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:50:15] INFO     Creating nearest neighbour lists                                 ]8;id=119278;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=546844;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:50:18] INFO     Calculate offloads: 7615 x 7615 x 2                              ]8;id=8082;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=210652;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:50:29] INFO     Done!                                                                 ]8;id=193912;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=859461;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=954081;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=293871;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=848881;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=653010;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=166621;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=663090;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=495765;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=826288;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
#                     INFO     Update offload durations.                                        ]8;id=851583;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=797157;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
#                     INFO     Done                                                                 ]8;id=755270;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=331310;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=558654;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=658844;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:50:59] INFO     Done generating routes                                               ]8;id=104955;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=493279;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#175\175]8;;\
# Number of routes: 9
#                     INFO     Preparing scenario outputs...                                        ]8;id=404544;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=833231;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#179\179]8;;\
# [07/01/23 00:51:11] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=141429;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=219518;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=451908;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=942466;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=90316;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=34779;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#196\196]8;;\
#                     INFO     Saving data to                                                     ]8;id=913655;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=266629;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              'resource_summary_table_arcs_only_fixed_speed_20220601'
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_066
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=2370;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=678860;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Preparing road network.......                                         ]8;id=277251;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=571567;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=782969;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=949632;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=979051;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=918033;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
# [07/01/23 00:51:12] INFO     Set depot                                                        ]8;id=217381;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=626034;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=886081;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=952862;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=764741;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=479320;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=588259;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=521636;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
# ...
#                     INFO     Setting demand for network                                       ]8;id=265472;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=212854;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=213936;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=903841;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
# [07/01/23 01:25:12] INFO     Update offload durations.                                        ]8;id=648658;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=282368;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
#                     INFO     Done                                                                 ]8;id=146820;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=435679;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=914645;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=6529;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 01:25:40] INFO     Done generating routes                                               ]8;id=749304;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=300984;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#175\175]8;;\
# Number of routes: 8
#                     INFO     Preparing scenario outputs...                                        ]8;id=118091;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=152454;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#179\179]8;;\
# [07/01/23 01:25:52] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=888294;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=692156;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
# [07/01/23 01:25:53] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=501087;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=403160;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=291823;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=863141;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#196\196]8;;\
#                     INFO     Saving data to                                                     ]8;id=980096;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=88121;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              'resource_summary_table_arcs_only_fixed_speed_20220601'
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_100
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=630943;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=577934;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Preparing road network.......                                         ]8;id=670393;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=379033;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=938723;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=786606;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=485533;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=929433;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=418578;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=638338;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=297651;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=663439;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=19019;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=131246;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
# [07/01/23 01:25:54] INFO     Checking master list                                             ]8;id=412131;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=590158;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     ERROR    Depot cannot have inverse arc.                                   ]8;id=195426;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=980626;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#402\402]8;;\
#                     INFO     Load distance matrix: 7548 x 7548                                ]8;id=738124;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=406804;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 01:25:59] INFO     Creating nearest neighbour lists                                 ]8;id=830200;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=373739;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 01:26:02] INFO     Calculate offloads: 7548 x 7548 x 2                              ]8;id=174720;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=346882;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 01:26:11] INFO     Done!                                                                 ]8;id=992518;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=133596;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=771052;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=666887;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=89398;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=728694;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=262815;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=776273;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=454035;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=43641;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
#                     INFO     Update offload durations.                                        ]8;id=232557;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=584339;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
# [07/01/23 01:26:12] INFO     Done                                                                 ]8;id=757671;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=479452;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=595407;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=857313;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 01:26:38] INFO     Done generating routes                                               ]8;id=578546;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=17142;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#175\175]8;;\
# Number of routes: 8
#                     INFO     Preparing scenario outputs...                                        ]8;id=744640;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=732041;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#179\179]8;;\
# [07/01/23 01:26:50] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=586252;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=876940;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=382625;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=324980;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=246644;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py\3708395786.py]8;;\:]8;id=649632;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_24272/3708395786.py#196\196]8;;\
#                     INFO     Saving data to                                                     ]8;id=83596;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=923256;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              'resource_summary_table_arcs_only_fixed_speed_20220601'
#                              (PartitionedDataSet)...
