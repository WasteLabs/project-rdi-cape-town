# %% [markdown]
# # Resource planning --- full

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# | Document info | |
# | --- | --- |
# | Area of interest: | Cape Town |
# | Planning type: | All REL type producers |
# | Prepared by: | Waste Labs (wastelabs.co) |
# | Prepared for: | Johan W. Joubert |
# | Contact: | elias@wastelabs.co |

# %%
# %load_ext kedro.ipython
# %reload_kedro
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.use_jedi=False
# Show all code cells outputs
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

import logging

logging.basicConfig(level=logging.INFO)

import pickle

#import chart_studio.plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)

#import cufflinks as cf

# cf.go_offline(connected=True)
# cf.set_config_file(colorscale="plotly", world_readable=True)

import os
import sys

import geopandas as gpd
import ipywidgets as widgets
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from GPSOdyssey import Kepler
from IPython.display import clear_output
from ipywidgets import fixed, interact, interact_manual, interactive
from keplergl import KeplerGl
from shapely import wkt

# sys.path.insert(0, '../../../mcarptif/')
# sys.path.insert(0, os.path.abspath('../../collection_diagnostics/'))
# sys.path.insert(0, os.path.abspath('../../OSM_processing/'))
import utils.process_gdf as process_gdf

# Extra options
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

from mcarptif.osmnx_network_extract.extract_grptif import NetworkExtract
from mcarptif.osmnx_network_extract.network_code import create_gdf, required_arc_plot
from mcarptif.solver.solve import solve_store_instance
from mcarptif.visualise.route_tables import RouteSummary
from utils.gdf_helpers import create_gdf


def df_style(df):
    if df[0] == "Total":
        return ["font-weight: bold"] * len(df)
    else:
        return [""] * len(df)
# Out:
# [07/01/23 00:20:52] INFO     Resolved project path as:                                              ]8;id=307060;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=670331;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#136\136]8;;\
#                              /Users/ejwillemse/dev/projects/project-rdi-cape-town.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/01/23 00:20:53] WARNING  /Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/importlib/__in ]8;id=941839;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=383661;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              it__.py:126: DeprecationWarning: `kedro.extras.datasets` is deprecated
#                              and will be removed in Kedro 0.19, install `kedro-datasets` instead by
#                              running `pip install kedro-datasets`.
#                                return _bootstrap._gcd_import(name[level:], package, level)
#                     INFO     NumExpr defaulting to 8 threads.                                          ]8;id=273241;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/numexpr/utils.py\utils.py]8;;\:]8;id=348906;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/numexpr/utils.py#160\160]8;;\
# [07/01/23 00:20:54] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=393794;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=465328;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely
#                              GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS
#                              version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions
#                              between both will be slow.
#                                warnings.warn(
# [07/01/23 00:20:55] INFO     Kedro project Project RDI Cape Town                                    ]8;id=630884;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=408264;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#105\105]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=30865;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=289622;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#106\106]8;;\
#                              'pipelines'
#                     INFO     Resolved project path as:                                              ]8;id=853181;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=133189;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#136\136]8;;\
#                              /Users/ejwillemse/dev/projects/project-rdi-cape-town.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/01/23 00:20:56] INFO     Kedro project Project RDI Cape Town                                    ]8;id=751143;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=767650;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#105\105]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=836133;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=645719;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#106\106]8;;\
#                              'pipelines'
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=907321;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=980491;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning:
#
#                              Using slow pure-python SequenceMatcher. Install python-Levenshtein to
#                              remove this warning
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=567165;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=726302;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/pyximport/pyximport.py:51: DeprecationWarning:
#
#                              the imp module is deprecated in favour of importlib and slated for
#                              removal in Python 3.12; see the module's documentation for alternative
#                              uses

# %% [markdown]
# ## Load network data

# %%
networkh5_file = "../data/05_model_input/sp_files/road_network_simplified_24645.h"
test_network = catalog.load("road_network_simplified_24645_edges")
test_network = test_network.drop(columns=["Unnamed: 0"], errors="ignore")
test_network_directed = catalog.load("road_network_simplified_24645_edges_directed")
nodes = catalog.load("road_network_simplified_24645_nodes")
# Out:
# [07/01/23 00:20:57] INFO     Loading data from 'road_network_simplified_24645_edges'            ]8;id=388746;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=659068;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (GeoJSONDataSet)...
# [07/01/23 00:21:04] INFO     Loading data from 'road_network_simplified_24645_edges_directed'   ]8;id=428063;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=271200;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (GeoJSONDataSet)...
# [07/01/23 00:21:09] INFO     Loading data from 'road_network_simplified_24645_nodes'            ]8;id=823483;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=423496;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (GeoJSONDataSet)...

# %%
test_network.shape
# Out:
# (22189, 19)

# %%
# %%time
test_network = process_gdf.process_edges(test_network)
test_network.drop_duplicates(["geom_id"], inplace=True)
nodes.sp_index = nodes.index
test_network["arc_index"] = test_network.index
nodes["sp_index"] = nodes.index
# Out:
# [07/01/23 00:21:13] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3 ]8;id=271816;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=879566;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              .10/site-packages/geopandas/geodataframe.py:205: UserWarning:
#
#                              Pandas doesn't allow columns to be created via a new attribute name -
#                              see
#                              https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-a
#                              ccess
# CPU times: user 2.5 s, sys: 54.5 ms, total: 2.56 s
# Wall time: 2.66 s

# %% [markdown]
# ## Run scenarios

# %%
# %%time
df_lat_lon_match = catalog.load("lat_lon_key_network_match_20220601")
df_producer_geo_all = catalog.load("syn_pop_scenarios_local_20220601")
infrastructure = catalog.load("infrastructure_sample_network_match")
solved = list(catalog.load("resource_summary_table_fixed_speed_20220601"))
# Out:
#                     INFO     Loading data from 'lat_lon_key_network_match_20220601'             ]8;id=723420;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=371248;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (CSVDataSet)...
#                     INFO     Loading data from 'syn_pop_scenarios_local_20220601'               ]8;id=694219;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=499804;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Loading data from 'infrastructure_sample_network_match'            ]8;id=328637;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=146158;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (CSVDataSet)...
#                     INFO     Loading data from 'resource_summary_table_fixed_speed_20220601'    ]8;id=996175;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=812253;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
# CPU times: user 173 ms, sys: 30.9 ms, total: 204 ms
# Wall time: 207 ms

# %%
# keys_all = list(df_producer_geo_all)
# key = keys_all[0]

# routing_parameters = catalog.load(
#     "routing_parameters"
# )
# df_producer_geo = df_producer_geo_all[key]()
# df_producer_geo_waste = catalog.load("waste_gen_scenarios_local_20220601")[key]()

def assign_demand(df_producer_geo, df_lat_lon_match, df_producer_geo_waste, routing_parameters):
    df_producer_geo["lat_lon_id"] = (
        df_producer_geo[["parcelLat", "parcelLon"]]
        .round(8)
        .astype(str)
        .agg("-".join, axis=1)
    )
    df_producer_geo = df_producer_geo.merge(df_lat_lon_match, left_on="lat_lon_id", right_on="lat_lon_id")

    df_producer_geo = df_producer_geo.merge(
        test_network[["arc_id", "geom_id", "geom_id_inv", "geom_id_order", "arc_index"]],
        validate="m:1",
    )
    df_producer_geo["land_use"] = df_producer_geo["mainDwellingType"].fillna("nan")


    df_producer_geo_waste = df_producer_geo_waste.loc[df_producer_geo_waste["id"] != 0.01]
    df_producer_geo_waste = df_producer_geo_waste.loc[df_producer_geo_waste["id"].isin(df_producer_geo["id"])]
    routing_parameters.fillna(0, inplace=True)

    calculate = ["bin_service_cost"]
    df_producer_geo.drop(columns=calculate, inplace=True, errors="ignore")
    df_producer_geo["Domestic"] = 1
    df_producer_geo["Non Domestic"] = 0
    df_producer_geo["H/M"] = 0
    df_producer_geo["category"] = "Landed"
    df_producer_geo["land_use"] = "Landed"
    df_producer_geo["total units"] = 1
    df_producer_geo["total_people"] = 1
    df_producer_geo["Postal Code"] = df_producer_geo["id"]

    df_producer_geo = df_producer_geo.merge(routing_parameters)
    df_producer_geo = df_producer_geo.merge(
        df_producer_geo_waste, how="left", validate="1:1"
    )
    df_producer_geo["demand"] = df_producer_geo["waste"]
    df_producer_geo["bin_service_cost"] = 0 #df_producer_geo["bin_service_cost"] * df_producer_geo["total units"]
    return df_producer_geo

# %%
# %reload_kedro
keys_all = list(df_producer_geo_all)
routing_parameters = catalog.load(
    "routing_parameters"
)
for keys in keys_all:
    if keys[0] == ".": continue
    if keys in solved: continue
    print(f"\n\n RUNNING SCENARIO {keys}")

    df_producer_geo = df_producer_geo_all[keys]()
    df_producer_geo_waste = catalog.load("waste_gen_scenarios_local_20220601")[keys]()
    df_producer_geo = assign_demand(df_producer_geo, df_lat_lon_match, df_producer_geo_waste, routing_parameters)
 
    # print("\n# offloads (12t)")
    # df_producer_geo.groupby("land_use")["demand"].sum() / 12000  # number of offloads
    # print("\n# units")
    # df_producer_geo.groupby("land_use")["total units"].sum()
    # print("\n# shifts (bin service cost)")
    # df_producer_geo.groupby("land_use")["bin_service_cost"].sum() / (
    #     3600 * 8
    # )  # number of shifts

    key_pois = infrastructure
    key_pois["Postal Code"] = key_pois["id"]

    key_pois["u"] = key_pois["arc_u"]
    key_pois["v"] = key_pois["arc_v"]
    key_pois["key"] = 0
    key_pois["geometry_point"] = key_pois["geometry"]
    key_pois["geometry"] = key_pois["geometry_arc"]
    key_pois = process_gdf.process_edges(key_pois)
    key_pois["geometry"] = key_pois["geometry_point"]
    key_pois = key_pois.merge(test_network[["arc_id", "arc_index"]], validate="1:1")

    offload = key_pois.loc[(key_pois["type"] != "depot")]

    key_depos = key_pois.loc[key_pois["type"] == "depot"]
    key_pois_list = list(key_depos["description"].unique())

    description = "Depot 2"

    key_depot_select = key_depos.copy()
    key_depot_select = key_depot_select.loc[key_depot_select["description"] == description]
    depot_arc_index = key_depot_select.iloc[0]["arc_index"]
    offload = key_pois.loc[key_pois["type"] != "depot"]

    descriptions = ["Offload 2", "Offload 3"]

    key_if_select = offload.copy()
    key_if_select = key_if_select.loc[key_if_select["description"].isin(descriptions)]
    if_arc_index = key_if_select["arc_index"].values

    key_list = list(df_producer_geo["category"].unique())

    descriptions = ["Landed"]

    bad_arcs = [
        "[(18.4571747, -33.9584372), (18.457166, -33.9585368), (18.457156, -33.9585885), (18.4571405, -33.9586324), (18.4571204, -33.9586875), (18.4570842, -33.9587648), (18.4568647, -33.9591331), (18.4568633, -33.9591415), (18.4568634, -33.9591465), (18.4568651, -33.9591518), (18.4568693, -33.9591571), (18.4568826, -33.9591636), (18.4570165, -33.9592207), (18.4570237, -33.9592212), (18.4570302, -33.9592194), (18.4570376, -33.9592149), (18.4570447, -33.9592066), (18.4570542, -33.9591921), (18.457325, -33.958752), (18.4573407, -33.9587173), (18.4573555, -33.9586744), (18.4573665, -33.9586219), (18.4573672, -33.9585957), (18.4573652, -33.958564), (18.4573568, -33.9585404), (18.4573451, -33.9585162), (18.457334, -33.9585017), (18.4573196, -33.9584906), (18.4573008, -33.9584812), (18.457278, -33.9584717), (18.4571747, -33.9584372)]"
    ]

    prod_select = df_producer_geo.copy()
    prod_select = prod_select.loc[~prod_select["geom_id_order"].isin(bad_arcs)]
    prod_select = prod_select.loc[prod_select["category"].isin(descriptions)]

    logging.info("Preparing road network.......\n")
    nodes["u"] = nodes["osmid"]
    network_info = NetworkExtract(
        test_network,
        test_network_directed,
        nodes,
        networkh5_file,
        round_cost=True,
        key_pois=key_pois,
    )
    
    depot = depot_arc_index
    ifs = if_arc_index
    req_arcs = network_info.arc_consolidation_standard(prod_select)
    network_info.load_required_arcs(req_arcs, merge_network=True)
    network_info.set_depot_arc(depot)
    network_info.set_if_arcs(ifs)
    network_info.loc_in_required_arcs()

    network_info.extend_required_inverse_arcs()

    network_info.check_main_list()
    network_info.load_distance_matrix()
    network_info.offload_calculations3D()

    network_info.network_gdf(prod_select)

    logging.info("Done!")

    cut_off = 100000
    bad_arcs = []
    for i in range(len(network_info.d)):
        if network_info.d[i, 0] > cut_off:
            bad_arc = network_info.reqArcList[i]
            bad_links = test_network.loc[test_network["arc_index"] == bad_arc]
            bad_arcs += bad_links["geom_id_order"].tolist()
    assert len(bad_arcs) == 0
    

    cut_off = 100000
    bad_arcs = []
    for i in range(len(network_info.d)):
        if network_info.d[0, i] > cut_off:
            bad_arc = network_info.reqArcList[i]
            bad_links = test_network.loc[test_network["arc_index"] == bad_arc]
            bad_arcs += bad_links["geom_id_order"].tolist()
    assert len(bad_arcs) == 0
    

    d_max = network_info.d.max()
    if d_max == np.inf:
        d_i = network_info.d.argmax(axis=0)[0]
        bad_arc = network_info.reqArcList[d_i]
        print(network_info.d[d_i, :])
        print(network_info.d[:, d_i])
        d_i2 = network_info.d[d_i, :].argmax()
        bad_arc2 = network_info.reqArcList[d_i2]
        print(network_info.d[d_i2, :])
        print(network_info.d[:, d_i2])
        test_network.loc[test_network["arc_index"] == bad_arc]
        test_network.loc[test_network["arc_index"] == bad_arc2]

    scenario_name = "Landed refuse"
    schedule_select = "weekly"
    offload_time = 15 * 60
    max_duration = 10.5 * 3600
    capacity = 10.5 * 1000
    travel_speed = 45 / 3.6
    service_speed = 5 / 3.6 # vs 35

    demand_increase_factor = {"daily": 1, "weekly": 1, "two_one": 1}
    increase_factor = demand_increase_factor[schedule_select]

    logging.info("Uploading scenario inputs...")
    prod_select_update = prod_select.copy()
    prod_arc_update = prod_select_update.copy()

    network_info.producer_demand = prod_arc_update
    prod_arc_update = network_info.add_demand_service_cost_to_ars(
        prod_select_update, service_speed
    )
    _ = pd.DataFrame(
        prod_arc_update.drop(columns=["arc_index"]).sum(numeric_only=True)
    ).astype(int)

    network_info.set_travel_speed(travel_speed)
    network_info.set_service_cost_and_demand(prod_arc_update)
    network_info.set_offload_time(offload_time)
    network_info.check_shapes()

    network_info.update_cost_matrix()
    network_info.update_offload_cost()

    network_info.set_vechile_capacity_constraint(capacity)
    network_info.set_vehicle_duration_constraint(max_duration)
    logging.info("Done")

    solution_df = solve_store_instance(
        "",
        improve=None,
        write_results=False,
        info=network_info,
        overwrite=True,
        test_solution=False,
        full_output=False,
        tollerance=60,
        nnFracLS=1,
        nnFracTS=0.25,
    )
    logging.info("Done generating routes")
    n_route = solution_df["route"].max() + 1
    print(f"Number of routes: {n_route}")

    logging.info("Preparing scenario outputs...")

    network_info.extend_prop_info()
    network_info.add_solution(solution_df, order=False)
    network_info.deconstruct_solution()

    network_info.vehicle_collection_schedule(schedule=schedule_select)
    network_info.extract_wide_offload_totals()

    network_info.add_traversal_time()
    network_info.add_time_formatted()
    network_info.add_constant_duration_time()

    _ = network_info.full_producer_report()

    route_summary = RouteSummary(network_info)
    route_sum_table = route_summary.route_summary()
    logging.info("Done preparing output")
    catalog.save("resource_summary_table_fixed_speed_20220601", {keys: route_sum_table})
    pass
# Out:
#                     INFO     Resolved project path as:                                              ]8;id=768194;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=92670;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#136\136]8;;\
#                              /Users/ejwillemse/dev/projects/project-rdi-cape-town.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/01/23 00:21:14] INFO     Kedro project Project RDI Cape Town                                    ]8;id=45658;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=958396;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#105\105]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=364488;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=9432;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/ipython/__init__.py#106\106]8;;\
#                              'pipelines'
#                     INFO     Loading data from 'routing_parameters' (ExcelDataSet)...           ]8;id=166288;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=972501;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#  RUNNING SCENARIO households_082
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=540253;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=793184;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
# [07/01/23 00:21:15] INFO     Preparing road network.......                                         ]8;id=408009;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=373902;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=429524;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=352521;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=554244;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=847358;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=258443;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=640246;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=717308;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=90111;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=853316;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=764775;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=237228;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=109965;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     INFO     Load distance matrix: 8122 x 8122                                ]8;id=14544;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=53197;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:21:23] INFO     Creating nearest neighbour lists                                 ]8;id=211055;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=494999;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:21:27] INFO     Calculate offloads: 8122 x 8122 x 2                              ]8;id=890373;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=89783;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:21:37] INFO     Done!                                                                 ]8;id=397714;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=290602;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=341160;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=732414;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=643501;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=929985;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=499349;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=337610;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=283426;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=306487;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
# [07/01/23 00:21:38] INFO     Update offload durations.                                        ]8;id=59637;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=939888;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
#                     INFO     Done                                                                 ]8;id=846454;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=398246;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=175115;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=503149;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:22:03] INFO     Done generating routes                                               ]8;id=782505;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=451614;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#175\175]8;;\
# Number of routes: 11
#                     INFO     Preparing scenario outputs...                                        ]8;id=597819;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=529184;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#179\179]8;;\
# [07/01/23 00:22:17] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=968898;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=691831;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=608457;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=175158;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=205021;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=643692;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#196\196]8;;\
#                     INFO     Saving data to 'resource_summary_table_fixed_speed_20220601'       ]8;id=850734;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=57153;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_083
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=993386;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=298838;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Preparing road network.......                                         ]8;id=471123;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=822932;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=710089;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=58451;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=48768;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=390100;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=935748;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=943053;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=369518;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=503855;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=165657;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=820753;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
# [07/01/23 00:22:18] INFO     Checking master list                                             ]8;id=660587;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=753458;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     INFO     Load distance matrix: 8129 x 8129                                ]8;id=359704;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=929232;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:22:24] INFO     Creating nearest neighbour lists                                 ]8;id=619319;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=254514;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:22:28] INFO     Calculate offloads: 8129 x 8129 x 2                              ]8;id=725592;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=394268;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:22:39] INFO     Done!                                                                 ]8;id=335113;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=920549;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=438300;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=579127;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=807832;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=391541;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=252781;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=702047;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=400898;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=742219;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
#                     INFO     Update offload durations.                                        ]8;id=545460;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=389679;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
# [07/01/23 00:22:40] INFO     Done                                                                 ]8;id=278771;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=257654;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=217191;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=355592;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:23:04] INFO     Done generating routes                                               ]8;id=696998;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=511684;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#175\175]8;;\
# Number of routes: 11
#                     INFO     Preparing scenario outputs...                                        ]8;id=717352;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=870520;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#179\179]8;;\
# [07/01/23 00:23:17] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=534381;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=215909;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=442896;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=260790;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=336194;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=936436;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#196\196]8;;\
#                     INFO     Saving data to 'resource_summary_table_fixed_speed_20220601'       ]8;id=384660;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=981481;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_084
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=504769;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=827128;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
# [07/01/23 00:23:18] INFO     Preparing road network.......                                         ]8;id=329256;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=935378;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=413022;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=469699;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=344743;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=143201;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=520531;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=419508;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=240405;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=570340;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=346277;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=536128;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=639199;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=697696;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     INFO     Load distance matrix: 8157 x 8157                                ]8;id=525950;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=899377;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:23:25] INFO     Creating nearest neighbour lists                                 ]8;id=522010;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=436946;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:23:29] INFO     Calculate offloads: 8157 x 8157 x 2                              ]8;id=687602;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=743673;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:23:41] INFO     Done!                                                                 ]8;id=174090;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=197647;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=339157;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=421016;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=306483;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=276811;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=135588;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=671591;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=910071;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=121245;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
#                     INFO     Update offload durations.                                        ]8;id=227946;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=81752;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
# [07/01/23 00:23:42] INFO     Done                                                                 ]8;id=489475;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=876406;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=433784;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=665270;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:24:09] INFO     Done generating routes                                               ]8;id=188233;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=619286;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#175\175]8;;\
# Number of routes: 11
#                     INFO     Preparing scenario outputs...                                        ]8;id=744959;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=938113;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#179\179]8;;\
# [07/01/23 00:24:26] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=538263;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=735574;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=61172;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=508624;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=189379;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=746042;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#196\196]8;;\
#                     INFO     Saving data to 'resource_summary_table_fixed_speed_20220601'       ]8;id=388979;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=325313;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_085
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=292780;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=864216;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Preparing road network.......                                         ]8;id=215443;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=937645;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=900144;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=142350;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=262230;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=139470;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
# [07/01/23 00:24:27] INFO     Set depot                                                        ]8;id=260617;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=774723;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=52681;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=694565;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=399852;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=961069;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=114603;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=946758;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     INFO     Load distance matrix: 8144 x 8144                                ]8;id=880088;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=17720;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:24:34] INFO     Creating nearest neighbour lists                                 ]8;id=583696;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=717469;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:24:37] INFO     Calculate offloads: 8144 x 8144 x 2                              ]8;id=503343;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=35839;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:24:49] INFO     Done!                                                                 ]8;id=634966;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=335321;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#93\93]8;;\
# [07/01/23 00:24:50] INFO     Uploading scenario inputs...                                         ]8;id=818690;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=842936;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=732185;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=348851;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=287587;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=675364;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=289894;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=263318;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
#                     INFO     Update offload durations.                                        ]8;id=791124;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=461917;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
# [07/01/23 00:24:51] INFO     Done                                                                 ]8;id=491874;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=485707;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=781139;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=599322;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:25:17] INFO     Done generating routes                                               ]8;id=933085;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=146834;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#175\175]8;;\
# Number of routes: 11
#                     INFO     Preparing scenario outputs...                                        ]8;id=797005;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=574555;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#179\179]8;;\
# [07/01/23 00:25:32] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=608628;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=924791;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=305616;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=360317;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=848729;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=284733;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#196\196]8;;\
#                     INFO     Saving data to 'resource_summary_table_fixed_speed_20220601'       ]8;id=677736;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=139791;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_086
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=821499;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=970457;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
# [07/01/23 00:25:33] INFO     Preparing road network.......                                         ]8;id=92101;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=246242;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=516644;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=100924;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=99665;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=977951;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=412294;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=262402;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
#                     INFO     Set offload facilities                                           ]8;id=443559;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=188527;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=1725;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=458776;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=417763;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=457373;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     INFO     Load distance matrix: 8142 x 8142                                ]8;id=915591;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=89326;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:25:40] INFO     Creating nearest neighbour lists                                 ]8;id=599679;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=662827;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:25:44] INFO     Calculate offloads: 8142 x 8142 x 2                              ]8;id=942750;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=73111;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:25:54] INFO     Done!                                                                 ]8;id=269335;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=614960;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=772388;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=552726;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#139\139]8;;\
# ...
#                     INFO     Uploading scenario inputs...                                         ]8;id=377646;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=54646;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=241160;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=626413;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=393346;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=614277;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=495569;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=16271;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
# [07/01/23 00:40:14] INFO     Update offload durations.                                        ]8;id=575956;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=39691;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
#                     INFO     Done                                                                 ]8;id=956339;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=637915;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=608233;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=981792;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:40:41] INFO     Done generating routes                                               ]8;id=977926;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=638065;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#175\175]8;;\
# Number of routes: 11
#                     INFO     Preparing scenario outputs...                                        ]8;id=533690;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=500650;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#179\179]8;;\
# [07/01/23 00:40:57] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=631046;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=475660;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=868311;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=599620;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=869440;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=710143;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#196\196]8;;\
#                     INFO     Saving data to 'resource_summary_table_fixed_speed_20220601'       ]8;id=236289;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=481517;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              (PartitionedDataSet)...
#  RUNNING SCENARIO households_100
#                     INFO     Loading data from 'waste_gen_scenarios_local_20220601'             ]8;id=901696;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=587994;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#345\345]8;;\
#                              (PartitionedDataSet)...
#                     INFO     Preparing road network.......                                         ]8;id=588979;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=4808;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#66\66]8;;\
#                     INFO     Load required arcs                                               ]8;id=155728;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=730265;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#231\231]8;;\
#                     INFO     Merging with the network                                         ]8;id=539133;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=950988;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#237\237]8;;\
#                     INFO     Set depot                                                        ]8;id=446062;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=543078;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#254\254]8;;\
# [07/01/23 00:40:58] INFO     Set offload facilities                                           ]8;id=683767;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=729398;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#267\267]8;;\
#                     INFO     Extend required arcs with inverse edge arcs                      ]8;id=3338;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=256357;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#290\290]8;;\
#                     INFO     Checking master list                                             ]8;id=269906;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=371544;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#392\392]8;;\
#                     INFO     Load distance matrix: 8131 x 8131                                ]8;id=232894;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=143015;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#425\425]8;;\
# [07/01/23 00:41:05] INFO     Creating nearest neighbour lists                                 ]8;id=560618;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=706269;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#464\464]8;;\
# [07/01/23 00:41:09] INFO     Calculate offloads: 8131 x 8131 x 2                              ]8;id=469845;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=667718;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#498\498]8;;\
# [07/01/23 00:41:19] INFO     Done!                                                                 ]8;id=545465;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=73882;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#93\93]8;;\
#                     INFO     Uploading scenario inputs...                                         ]8;id=743577;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=538431;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#139\139]8;;\
#                     INFO     Setting service cost for network                                 ]8;id=612698;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=139293;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#585\585]8;;\
#                     INFO     Setting demand for network                                       ]8;id=707125;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=671762;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#601\601]8;;\
#                     INFO     Update travel durations.                                         ]8;id=33152;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=856563;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#533\533]8;;\
# [07/01/23 00:41:20] INFO     Update offload durations.                                        ]8;id=354140;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py\extract_grptif.py]8;;\:]8;id=550342;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/osmnx_network_extract/extract_grptif.py#539\539]8;;\
#                     INFO     Done                                                                 ]8;id=113435;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=738467;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#161\161]8;;\
#                     INFO     Problem info supplied. Directly proceeding to solve problem.              ]8;id=587328;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py\solve.py]8;;\:]8;id=791606;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/solver/solve.py#517\517]8;;\
# [07/01/23 00:41:45] INFO     Done generating routes                                               ]8;id=54417;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=925696;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#175\175]8;;\
# Number of routes: 11
#                     INFO     Preparing scenario outputs...                                        ]8;id=137517;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=102300;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#179\179]8;;\
# [07/01/23 00:42:01] WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=935614;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=919291;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:219: FutureWarning:
#
#                              The frame.append method is deprecated and will be removed from pandas
#                              in a future version. Use pandas.concat instead.
#                     WARNING  /Users/ejwillemse/dev/projects/project-rdi-cape-town/src/mcarptif/visu ]8;id=958235;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=240541;file:///Users/ejwillemse/.pyenv/versions/3.10.8/lib/python3.10/warnings.py#109\109]8;;\
#                              alise/route_tables.py:231: FutureWarning:
#
#                              In a future version, `df.iloc[:, i] = newvals` will attempt to set the
#                              values inplace instead of always setting a new array. To retain the
#                              old behavior, use either `df[df.columns[i]] = newvals` or, if columns
#                              are non-unique, `df.isetitem(i, newvals)`
#                     INFO     Done preparing output                                                ]8;id=306800;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py\4222221077.py]8;;\:]8;id=407538;file:///var/folders/dy/_xqj_wpj3jl0lgk31f6ytns00000gp/T/ipykernel_53395/4222221077.py#196\196]8;;\
#                     INFO     Saving data to 'resource_summary_table_fixed_speed_20220601'       ]8;id=383520;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=596486;file:///Users/ejwillemse/dev/projects/project-rdi-cape-town/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#384\384]8;;\
#                              (PartitionedDataSet)...
